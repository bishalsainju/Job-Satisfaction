# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

num_topic = 14
data_path = f"~/Desktop/R_js/data1/estimates/combo-{num_topic}.csv"
df = pd.read_csv(data_path)

# %%
df
# Out:
#     Unnamed: 0  Topic_Num   Pro_Con      Pro_Con_p  Job_Status  Job_Status_p
# 0            1          1 -0.028623  4.209286e-298   -0.009873  1.264572e-39
# 1            2          2 -0.088625   0.000000e+00    0.004371  2.696074e-03
# 2            3          3 -0.034336  1.650914e-219    0.008202  3.757669e-15
# 3            4          4 -0.002771   1.647801e-05   -0.004297  6.139172e-11
# 4            5          5  0.140385   0.000000e+00    0.013301  9.220363e-27
# 5            6          6 -0.089716   0.000000e+00   -0.006638  1.557989e-14
# 6            7          7  0.026866   0.000000e+00    0.000471  4.474731e-01
# 7            8          8 -0.124921   0.000000e+00   -0.008761  1.665846e-12
# 8            9          9  0.064056   0.000000e+00    0.004202  9.723199e-08
# 9           10         10  0.101139   0.000000e+00    0.001240  2.573777e-01
# 10          11         11  0.023504  3.446213e-181   -0.002797  1.956994e-04
# ...

# %%
g = sns.FacetGrid(data=df)
# g.map(plt.scatter, 'x', 'y')

ax = g.axes[0,0]
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

fig, axes = plt.subplots(figsize=(15,18))

p1 = sns.regplot(x="Pro_Con", y="Job_Status", data=df, fit_reg=False, marker="+" ,
                scatter_kws={'s':400})
# add annotations one by one with a loop
for line in range(0,df.shape[0]):
     p1.text(df.Pro_Con[line]+.002, df.Job_Status[line], df.Topic_Num[line], 
             horizontalalignment='left', size='large', color='black', weight='bold')

plt.xlabel("Con_Pro")
plt.ylabel("Former_Current")
plt.xlim([-.2, .2])
plt.ylim([-.2, .2])
plt.gcf().set_size_inches(10, 10)

import os
home = os.path.expanduser("~")
# plt.savefig(home + f"/Desktop/R_js/img/combo/{num_topic}/cov-combo.png")
plt.show()
