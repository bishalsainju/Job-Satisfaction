# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

num_topic = 20
data_path = f"~/Desktop/R_js/data1/estimates/combo-{num_topic}.csv"
df = pd.read_csv(data_path)

# %%
df
# Out:
#     Unnamed: 0  Topic_Num   Pro_Con      Pro_Con_p  Job_Status  Job_Status_p
# 0            1          1  0.033314   0.000000e+00   -0.003678  3.314695e-08
# 1            2          2 -0.009963   1.038963e-70   -0.002071  2.256939e-05
# 2            3          3  0.029829   0.000000e+00   -0.005567  4.523153e-16
# 3            4          4  0.042788   0.000000e+00   -0.005237  1.650800e-12
# 4            5          5 -0.032913   0.000000e+00    0.003548  1.404658e-05
# 5            6          6 -0.066268   0.000000e+00   -0.002418  1.834339e-04
# 6            7          7  0.002858   9.411128e-04    0.003332  9.132978e-05
# 7            8          8 -0.103117   0.000000e+00    0.003586  8.022563e-03
# 8            9          9 -0.051975   0.000000e+00    0.009150  2.386668e-24
# 9           10         10 -0.113881   0.000000e+00    0.006013  8.069931e-08
# 10          11         11  0.006966   5.363500e-59   -0.004226  3.806486e-20
# 11          12         12 -0.019822  1.543366e-293   -0.001613  1.124030e-02
# 12          13         13  0.120103   0.000000e+00   -0.000860  4.915535e-01
# 13          14         14 -0.008148   7.380643e-29   -0.000230  7.440723e-01
# 14          15         15  0.101517   0.000000e+00    0.006261  1.494919e-09
# 15          16         16  0.023517  1.763136e-279    0.003170  8.883745e-06
# 16          17         17  0.042372   0.000000e+00    0.003626  2.748535e-05
# 17          18         18 -0.012811   7.961630e-58    0.000199  8.062916e-01
# 18          19         19 -0.010743   3.915480e-65   -0.008351  4.746593e-37
# 19          20         20  0.026358   0.000000e+00   -0.004654  4.190048e-23

# %%
g = sns.FacetGrid(data=df)
# g.map(plt.scatter, 'x', 'y')

ax = g.axes[0,0]
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# ax.figure(figsize=(10, 10))
p1 = sns.regplot(x="Pro_Con", y="Job_Status", data=df, fit_reg=False, marker="+" ,
                scatter_kws={'s':400})
# add annotations one by one with a loop
for line in range(0,df.shape[0]):
     p1.text(df.Pro_Con[line]+.002, df.Job_Status[line], df.Topic_Num[line], 
             horizontalalignment='left', size='large', color='black', weight='bold')

plt.xlabel("Con_Pro")
plt.ylabel("Former_Current")
plt.xlim([-.15, .15])
plt.ylim([-.015, .02])
plt.gcf().set_size_inches(10, 10)

import os
home = os.path.expanduser("~")
plt.savefig(home + f"/Desktop/R_js/img/combo/{num_topic}/cov-combo.png")
plt.show()
