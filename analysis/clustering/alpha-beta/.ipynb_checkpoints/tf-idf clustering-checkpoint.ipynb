# %%
import pandas as pd
import numpy as np

num_topics = 26
proFilePath = "~/Desktop/R_js/data/pro_doc_sampled.csv"
df = pd.read_csv(proFilePath)
display(df.head())
print(df.shape)
# Out:
#    Unnamed: 0  Ratings  Job_Status  Reviewed_Year  \
# 0           0      2.0           1           2017
# 1           1      3.0           1           2015
# 2           2      2.0           0           2012
# 3           3      4.0           0           2017
# 4           4      1.0           1           2016
#
#                                          Review_Text  \
# 0                   hour lunch, friendly co-workers.
# 1   benefits, Medical, dental, myshare, 401k, stocks
# 2                discount card . schedule 3 on 3 off
# 3             good break lengths and plenty of hours
# 4  My pay was good and my schedule allowed me to ...
#
#                                             Px_Texts  \
# 0  cowork friendli hour lunch friendli_cowork hou...
# 1                benefit dental medic myshar stock
# 2               card discount schedul discount_card
# 3              break hour length plenti plenti_hour
# 4                 allow job pay schedul pay_schedul
#
#                                           Tknz_Texts  Doc_Length  Work_Life  \
# 0  ['cowork', 'friendli', 'hour', 'lunch', 'frien...           9        3.0
# 1  ['benefit', 'dental', 'medic', 'myshar', 'stock']           5        3.0
# 2   ['card', 'discount', 'schedul', 'discount_card']           4        1.0
# 3  ['break', 'hour', 'length', 'plenti', 'plenti_...           5        4.0
# 4  ['allow', 'job', 'pay', 'schedul', 'pay_schedul']           5        3.0
#
#    Benefits  Job_Advancement  Management  Culture  Company_Index Company_Name
# 0       2.0              2.0         1.0      3.0              1      Walmart
# 1       4.0              4.0         3.0      3.0              1      Walmart
# 2       4.0              3.0         1.0      3.0              1      Walmart
# 3       3.0              3.0         4.0      4.0              1      Walmart
# 4       3.0              1.0         1.0      1.0              1      Walmart
# (33624, 15)

# %%
corpus = df.Px_Texts.tolist()
a = ' '.join(sent for sent in corpus)
a = a.split(" ")
a = list(set(a))
print(len(a));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-0f12f45c90de> in <module>
#       3 a = a.split(" ")
#       4 a = list(set(a))
# ----> 5 print(a.length)
#
# AttributeError: 'list' object has no attribute 'length'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())
# Out:
# ['050_cent_hour', '10_discount_card', '10_discount_employe', '10_discount_flexibl', '10_discount_friendli', '10_discount_groceri', '10_discount_item', '10_discount_kroger', '10_discount_merchandis', '10_discount_purchas', '10_discount_stock', '10_discount_store', '10_employe_discount', '10_feet_cloth', '10_hour_day', '10_hour_shift', '10_kroger_brand', '10_kroger_item', '10_kroger_product', '10_min_break', '10_minut_break', '10_percent_discount', '10_store_brand', '10_team_discount', '128_hour_pto', '12_hour_shift', '12_hr_shift', '14_day_pto', '1500_tax_bi', '15_min_break', '15_minut_break', '15_minut_paid', '1_hour_break', '1_hour_lunch', '1_hr_lunch', '1hr_lunch_break', '1st_day_start', '20_day_vacat', '20_discount_cv', '20_discount_name', '25_cent_drink', '25_cent_soda', '2_15_min', '2_15_minut', '2_break_hour', '2_break_lunch', '2_children_wife', '2_day_home', '2_day_pto', '2_day_week', '2_fifteen_minut', '2_paid_15', '2_pc_staff', '30_cv_brand', '30_discount_cv', '30_local_averag', '30_min_1', '30_min_break', '30_min_hour', '30_min_lunch', '30_minut_break', '30_minut_lunch', '30min_paid_break', '3_4_day', '3_day_benefit', '3_day_free', '3_day_shift', '3_day_week', '3_day_weekend', '3_week_paid', '3_week_vacat', '401_invest_wonder', '401_tuition_reimburs', '401k_benefit_retir', '401k_close_bond', '401k_discount_cabl', '401k_famili_atmospher', '401k_flexibl_schedul', '401k_health_benefit', '401k_health_care', '401k_health_insur', '401k_life_balanc', '401k_match_6', '401k_match_annual', '401k_match_benefit', '401k_match_paid', '401k_match_pay', '401k_match_pto', '401k_match_qualiti', '401k_match_schedul', '401k_opportun_advanc', '401k_paid_time', '401k_paid_vacat', '401k_pension_plan', '401k_profit_share', '401k_referr_bonu', '401k_stock_option', '401k_stock_paid', '401k_stock_plan', '401k_variou_compens', '401k_worklif_balanc', '40_hour_week', '45_min_lunch', '45_minut_lunch', '45_paid_holiday', '4_10_hour', '4_8_week', '4_day_3', '4_day_shift', '4_day_week', '4_hour_shift', '4_month_matern', '4_week_paid', '4_week_sabbat', '4_week_vacat', '50_att_servic', '50_cell_phone', '50_cent_drink', '50_phone_bill', '58hour_pay_period', '5_hour_day', '5_meal_free', '60_day_accid', '6_month_evalu', '7day_break_week', '8_hour_day', '8_hour_shift', '90_day_benefit', '95_benefit_pto', '980_schedul_cloth', '980_schedul_life', '_plant', '_plant_lot', 'aad', 'aaohn', 'aawesom', 'abc', 'abc_truli', 'abd', 'abd_srink', 'abil', 'abil_advanc', 'abil_bring', 'abil_cbt', 'abil_cbt_offsit', 'abil_chang', 'abil_chang_posit', 'abil_differ', 'abil_gain', 'abil_grow', 'abil_home', 'abil_home_flexibl', 'abil_learn', 'abil_leav', 'abil_leav_exercis', 'abil_move', 'abil_reach', 'abil_reach_potenti', 'abil_remot', 'abil_remot_benefit', 'abil_remot_ccie', 'abil_remot_home', 'abil_remot_team', 'abil_telecommut', 'abil_telecommut_benefit', 'abilt', 'abilti', 'abl', 'abl_help', 'abl_help_custom', 'abl_help_peopl', 'abl_home', 'abl_hour', 'abl_learn', 'abl_listen', 'abl_listen_music', 'abl_overrid', 'abl_remot', 'abl_resolv', 'ablil', 'abliti', 'abound', 'abound_cafeteria', 'abound_cafeteria_lot', 'abour', 'aboveaverag', 'abovesit', 'abroad', 'absenc', 'absens', 'absolut', 'abund', 'abundantli', 'abus', 'ac', 'acceler', 'accept', 'accerler', 'access', 'access_benefit', 'access_free_class', 'access_googl', 'access_gym', 'access_interst', 'access_learn_materi', 'access_lot', 'access_manag', 'access_manag_cultur', 'access_shuttl', 'access_technolog', 'access_wonder', 'access_world', 'access_xbox', 'accesslimit', 'accessori', 'accid', 'accid_free', 'accid_free_day', 'accident', 'accomad', 'accommod', 'accomod', 'accomplish', 'accomplish_start', 'accomplish_start_shift', 'accord', 'accordingli', 'account', 'account_benefit', 'accoutn', 'accross', 'accru', 'accrual', 'accumul', 'accur', 'accur_data', 'accur_data_dictionari', 'accuraci', 'acess', 'acheiv', 'achiev', 'achiev_financi_goal', 'acknowledg', 'acquir', 'acru', 'action', 'action_committe', 'action_committe_ ...

# %%
print(X.shape)
# Out:
# (33624, 14889)

# %%
print(X)
# Out:
#   (0, 3284)	0.21180008681254953
#   (0, 6366)	0.22562128865455408
#   (0, 7330)	0.18178826185852678
#   (0, 8500)	0.16436623714910692
#   (0, 6380)	0.31722621839827325
#   (0, 7401)	0.2547202245906755
#   (0, 8623)	0.44195934789187497
#   (0, 7416)	0.4955437904326825
#   (0, 8624)	0.4876124951103687
#   (1, 954)	0.16032165757033914
#   (1, 3791)	0.4026799510087607
#   (1, 9019)	0.3778345298988164
#   (1, 9441)	0.7281164629415458
#   (1, 13137)	0.3731397962950537
#   (2, 2296)	0.5362353130354213
#   (2, 3966)	0.35683727261504206
#   (2, 12367)	0.37849296113714526
#   (2, 3992)	0.6647269577022564
#   (3, 7330)	0.22756217876577373
#   (3, 1805)	0.25755447771972395
#   (3, 8147)	0.6649642305269436
#   (3, 11178)	0.3895170896227531
#   (3, 11188)	0.5366378246205015
#   (4, 12367)	0.3064740482338342
#   (4, 400)	0.4557573598437274
#   :	:
#   (33620, 12301)	0.2915030332517039
#   (33620, 5428)	0.3353961648044164
#   (33620, 11370)	0.4049296114445065
#   (33620, 3035)	0.37015088530120255
#   (33620, 10836)	0.42040628138155167
#   (33621, 954)	0.18979303485112983
#   (33621, 13702)	0.29283256916189393
#   (33621, 13713)	0.5357759125746596
#   (33621, 5499)	0.5114626701904968
#   (33621, 5508)	0.5740886681223034
#   (33622, 954)	0.15300456360776044
#   (33622, 4166)	0.3779348207310274
#   (33622, 791)	0.2871930202514127
#   (33622, 14765)	0.33304542901291156
#   (33622, 14766)	0.33514066208209087
#   (33622, 1117)	0.5602169910567094
#   (33622, 13601)	0.46281037766803235
#   (33623, 3284)	0.20198120962326532
#   (33623, 5881)	0.14545814053667278
#   (33623, 8787)	0.1834668873805133
#   (33623, 3337)	0.3365300560934087
#   (33623, 8832)	0.4276117725257782
#   (33623, 13691)	0.4346332047146615
#   (33623, 7519)	0.3770921338278531
#   (33623, 7853)	0.5264756545685575
