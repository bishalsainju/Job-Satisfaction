# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

company_name = '5_Amazon'
file_path = f'~/Desktop/workspace/indeed/Job-Satisfaction/data/companies/{company_name}/{company_name[2:]}.csv'
df = pd.read_csv(file_path)

data_path = '~/Desktop/workspace/indeed/Job-Satisfaction/data/companies'

# %%
df.head()
# Out:
#    Unnamed: 0  Index  Rating_Number  Work_Life  Benefits  Job_Advancement  \
# 0           0      1            3.0        4.0       5.0              2.0
# 1           1      2            1.0        2.0       5.0              5.0
# 2           2      3            2.0        2.0       0.0              2.0
# 3           3      4            5.0        0.0       0.0              0.0
# 4           4      5            5.0        5.0       3.0              4.0
#
#    Management  Culture              Review_Title  \
# 0         4.0      3.0       The job was not bad
# 1         2.0      1.0          Very frustrating
# 2         2.0      2.0                Slave work
# 3         0.0      0.0  productive and fun place
# 4         3.0      4.0     A great place to work
#
#                  Reviewer_Job_Title Reviewer_Job_Status Reviewer_Job_Location  \
# 0                          Stocker      Former Employee     West Deptford, NJ
# 1                           Packer      Former Employee             Monee, IL
# 2            Fulfillment Associate      Former Employee    San Bernardino, CA
# 3  Senior User Experience Designer     Current Employee           Seattle, WA
# 4              Warehouse Associate     Current Employee        Hazel Park, MI
#
#   Reviewed_Date                                        Review_Text Pros Cons  \
# 0    2019-07-13  The job was good but overly fast paced hard to...  NaN  NaN
# 1    2019-07-13  Managers were not professional just the whole ...  NaN  NaN
# 2    2019-07-13  I have nothing to say really if you need a job...  NaN  NaN
# 3    2019-07-13  You can learn a lot very quickly in a very sho...  NaN  NaN
# 4    2019-07-13  I have nothing but positive things to say abou...  NaN  NaN
#
#    Reviewed_Year
# 0           2019
# 1           2019
# 2           2019
# 3           2019
# 4           2019

# %%
df['Reviewed_Date'] = pd.to_datetime(df['Reviewed_Date'])

# %%
df.head()
# Out:
#    Unnamed: 0  Index  Rating_Number  Work_Life  Benefits  Job_Advancement  \
# 0           0      1            3.0        4.0       5.0              2.0
# 1           1      2            1.0        2.0       5.0              5.0
# 2           2      3            2.0        2.0       0.0              2.0
# 3           3      4            5.0        0.0       0.0              0.0
# 4           4      5            5.0        5.0       3.0              4.0
#
#    Management  Culture              Review_Title  \
# 0         4.0      3.0       The job was not bad
# 1         2.0      1.0          Very frustrating
# 2         2.0      2.0                Slave work
# 3         0.0      0.0  productive and fun place
# 4         3.0      4.0     A great place to work
#
#                  Reviewer_Job_Title Reviewer_Job_Status Reviewer_Job_Location  \
# 0                          Stocker      Former Employee     West Deptford, NJ
# 1                           Packer      Former Employee             Monee, IL
# 2            Fulfillment Associate      Former Employee    San Bernardino, CA
# 3  Senior User Experience Designer     Current Employee           Seattle, WA
# 4              Warehouse Associate     Current Employee        Hazel Park, MI
#
#   Reviewed_Date                                        Review_Text Pros Cons  \
# 0    2019-07-13  The job was good but overly fast paced hard to...  NaN  NaN
# 1    2019-07-13  Managers were not professional just the whole ...  NaN  NaN
# 2    2019-07-13  I have nothing to say really if you need a job...  NaN  NaN
# 3    2019-07-13  You can learn a lot very quickly in a very sho...  NaN  NaN
# 4    2019-07-13  I have nothing but positive things to say abou...  NaN  NaN
#
#    Reviewed_Year
# 0           2019
# 1           2019
# 2           2019
# 3           2019
# 4           2019

# %%
df['Reviewed_Year'] = df['Reviewed_Date'].dt.year

# %%
df.head()
# Out:
#    Unnamed: 0  Index  Rating_Number  Work_Life  Benefits  Job_Advancement  \
# 0           0      1            3.0        4.0       5.0              2.0
# 1           1      2            1.0        2.0       5.0              5.0
# 2           2      3            2.0        2.0       0.0              2.0
# 3           3      4            5.0        0.0       0.0              0.0
# 4           4      5            5.0        5.0       3.0              4.0
#
#    Management  Culture              Review_Title  \
# 0         4.0      3.0       The job was not bad
# 1         2.0      1.0          Very frustrating
# 2         2.0      2.0                Slave work
# 3         0.0      0.0  productive and fun place
# 4         3.0      4.0     A great place to work
#
#                  Reviewer_Job_Title Reviewer_Job_Status Reviewer_Job_Location  \
# 0                          Stocker      Former Employee     West Deptford, NJ
# 1                           Packer      Former Employee             Monee, IL
# 2            Fulfillment Associate      Former Employee    San Bernardino, CA
# 3  Senior User Experience Designer     Current Employee           Seattle, WA
# 4              Warehouse Associate     Current Employee        Hazel Park, MI
#
#   Reviewed_Date                                        Review_Text Pros Cons  \
# 0    2019-07-13  The job was good but overly fast paced hard to...  NaN  NaN
# 1    2019-07-13  Managers were not professional just the whole ...  NaN  NaN
# 2    2019-07-13  I have nothing to say really if you need a job...  NaN  NaN
# 3    2019-07-13  You can learn a lot very quickly in a very sho...  NaN  NaN
# 4    2019-07-13  I have nothing but positive things to say abou...  NaN  NaN
#
#    Reviewed_Year
# 0           2019
# 1           2019
# 2           2019
# 3           2019
# 4           2019

# %%
fig, ax = plt.subplots(figsize=(15, 7))

df.groupby(['Reviewed_Year', 'Rating_Number'])['Rating_Number'].count().unstack().plot(ax=ax)

# %%
temp = df.groupby(['Reviewed_Year'])['Rating_Number'].value_counts(normalize=True)\
.mul(100).reset_index(name='Percentage')
sns.barplot(x='Reviewed_Year', y='Percentage', hue='Rating_Number', data=temp).set_title("Rating over Years")
# Out:
# Text(0.5, 1.0, 'Rating over Years')

# %%
#Let's see if that generalizes over all data

def merge_companies(companies_list=range(1, 51)):
    df_companies = pd.DataFrame()
    for company_index in companies_list:
        company_name = df_company_list.iloc[company_index - 1]['Company_Name']
        company_path = data_path + f'/companies/{company_index}_{company_name}/{company_name}.csv'
        df_company = pd.read_csv(company_path)
        df_companies = pd.concat([df_companies, df_company])
    return df_companies

df_companies = merge_companies()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-50e8adf6782b> in <module>
#      10     return df_companies
#      11
# ---> 12 df_comapnies = merge_companies()
#
# <ipython-input-39-50e8adf6782b> in merge_companies(companies_list)
#       4     df_companies = pd.DataFrame()
#       5     for company_index in companies_list:
# ----> 6         company_name = df_company_list.iloc[company_index - 1]['Company_Name']
#       7         company_path = data_path + f'/companies/{company_index}_{company_name}/{company_name}.csv'
#       8         df_company = pd.read_csv(company_path)
#
# NameError: name 'df_company_list' is not defined
