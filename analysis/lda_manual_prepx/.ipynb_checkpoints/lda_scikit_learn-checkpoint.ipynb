# %%
# Run in terminal or command prompt
# python3 -m spacy download en

import numpy as np
import pandas as pd
import re, nltk, spacy, gensim

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint

# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

#Gensim
from gensim.models import CoherenceModel

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

import os
root = os.path.expanduser('~')

company_index='5'
company_name='Amazon'
img_path = root + '/Desktop/workspace/indeed/Job-Satisfaction/img/companies/'+f'{company_index}_{company_name}'

if not os.path.exists(img_path):
    os.makedirs(img_path)

# %%
## making dataset

def get_px_data(company_index=5, company_name='Amazon', uni=False, bi=False, tri=False):
    data_path = root + '/Desktop/workspace/indeed/Job-Satisfaction/data/companies/'+f'{company_index}_{company_name}'+'/output_data/px_data/pros.csv'
    df = pd.read_csv(data_path)
    print(df.head())
    if uni and bi and tri:
        df_data = df['Unigrams'].fillna('') + ' ' + df['Bigrams'].fillna('') + ' ' + df['Trigrams'].fillna('')
    elif uni:
        df_data = df['Unigrams'].dropna()
    elif bi:
        df_data = df['Bigrams'].dropna()
    elif tri:
        df_data = df['Trigrams'].dropna()
    
    return df_data.tolist()
    
def merge_data(company_list=[5], uni=False, bi=False, tri=False):
    sentences = []
    df_company_list = pd.read_csv( root + '/Desktop/workspace/indeed/Job-Satisfaction/data/scraper_data/review_site.csv')
    sentences = []
    for company_index in company_list:
        company_name = df_company_list.iloc[company_index - 1]['Company_Name']
        sentences.extend(get_px_data(company_index=company_index, company_name=company_name, 
                        uni=uni, bi=bi, tri=tri))
    return sentences

sentences = merge_data(company_list=[5, 6, 7],
                        uni=True, bi=True, tri=True)
# sentences = merge_data(company_list=range(1, 51),
#                         uni=True, bi=True, tri=True)
print(len(sentences))
sentences[:5]
# Out:
#    Unnamed: 0                                        Review_Text  \
# 0           0                                           Good pay
# 1           1  The only good part for me was it was close to ...
# 2           2               All ways an relxing work evironment.
# 3           3  Flexible scheduling around your life and your ...
# 4           4                                           Benefits
#
#                       Unigrams          Bigrams Trigrams
# 0                          pay              NaN      NaN
# 1                   close hous              NaN      NaN
# 2                          NaN              NaN      NaN
# 3  cowork flexibl life schedul  flexibl_schedul      NaN
# 4                      benefit              NaN      NaN
#    Unnamed: 0                               Review_Text             Unigrams  \
# 0           0                                  benefits              benefit
# 1           1  Egonomics and Safety were very important        egonom safeti
# 2           2          Free lunches, time off, good pay  free lunch pay time
# 3           3                         Exercise facility        exercis facil
# 4           4                          cant say nothing                  NaN
#
#                           Bigrams                        Trigrams
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2  free_lunch lunch_time time_pay  free_lunch_time lunch_time_pay
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                   Work environment
# 1           1                                     Teleoperador/a
# 2           2                         diversity, stock, benefits
# 3           3                      The benefits and work culture
# 4           4  I love the technology and the discounts that w...
#
#                          Unigrams         Bigrams Trigrams
# 0                         environ             NaN      NaN
# 1                             NaN             NaN      NaN
# 2            benefit divers stock   stock_benefit      NaN
# 3                  benefit cultur  benefit_cultur      NaN
# 4  discount love provid technolog             NaN      NaN
#    Unnamed: 0                                 Review_Text  \
# 0           0                             Good co-workers
# 1           1  You control your own hours..to some degree
# 2           2                                Great people
# 3           3                                        None
# 4           4                  Free meals, flexible hours
#
#                  Unigrams                              Bigrams  \
# 0                  cowork                                  NaN
# 1   control degre hoursto        control_hoursto hoursto_degre
# 2                   peopl                                  NaN
# 3                    none                                  NaN
# 4  flexibl free hour meal  flexibl_hour free_meal meal_flexibl
#
#                               Trigrams
# 0                                  NaN
# 1                control_hoursto_degre
# 2                                  NaN
# 3                                  NaN
# 4  free_meal_flexibl meal_flexibl_hour
#    Unnamed: 0                                        Review_Text  \
# 0           0                                3 Days in a row off
# 1           1  Benefits, There many different shifts, work ha...
# 2           2                   Free drinks, paid time, overtime
# 3           3  On your own, flexible, can keep job even worki...
# 4           4                                     Great benefits
#
#                                             Unigrams               Bigrams  \
# 0                                                day                   NaN
# 1  advanc benefit differ half hard holiday major ...                   NaN
# 2                       drink free overtim paid time  free_drink paid_time
# 3                                 flexibl month time          flexibl_time
# 4                                            benefit                   NaN
#
#   Trigrams
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                     Bravos, great team environment
# 1           1  Ability to use your talents and strenths. Grea...
# 2           2                         Benefits and compensations
# 3           3                              quiet room, cafeteria
# 4           4                                           Benefits
#
#              Unigrams          Bigrams Trigrams
# 0  bravo environ team     team_environ      NaN
# 1   abil talent train              NaN      NaN
# 2     benefit compens  benefit_compens      NaN
# 3     cafeteria quiet              NaN      NaN
# 4             benefit              NaN      NaN
#    Unnamed: 0              Review_Text     Unigrams      Bigrams Trigrams
# 0           0  Bosses are really nice.    boss nice          NaN      NaN
# 1           1                  Nothing          NaN          NaN      NaN
# 2           2             Great coders          NaN          NaN      NaN
# 3           3     Pto is very generous    gener pto          NaN      NaN
# 4           4     Great Pay & Benefits  benefit pay  pay_benefit      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                     Work as a team
# 1           1  Benefits, but only for full time, part time be...
# 2           2  opening at 9 gives us time when we come in at ...
# 3           3                                         Decent pay
# 4           4  Holiday pay, vacation time, flexible hours, mu...
#
#                                             Unigrams  \
# 0                                               team
# 1                                       benefit time
# 2                                     day start time
# 3                                         decent pay
# 4  career flexibl holiday hour multipl pay time v...
#
#                                             Bigrams           Trigrams
# 0                                               NaN                NaN
# 1               benefit_time time_benefit time_time                NaN
# 2                                               NaN                NaN
# 3                                        decent_pay                NaN
# 4  flexibl_hour holiday_pay time_flexibl vacat_time  time_flexibl_hour
#    Unnamed: 0                    Review_Text      Unigrams      Bigrams  \
# 0           0     Longevity, upward mobility  mobil upward          NaN
# 1           1  Work / Life balance is great.   balanc life  life_balanc
# 2           2                     Everything           NaN          NaN
# 3           3           Work with fun people     fun peopl          NaN
# 4           4                    Flexibility       flexibl          NaN
#
#   Trigrams
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                        My schedule
# 1           1  Occasional free lunches, benefits, everyone is...
# 2           2        Your work ends when you leave the building.
# 3           3                           Medical health insurance
# 4           4              Excellent career growth Opportunities
#
#                            Unigrams  \
# 0                           schedul
# 1  benefit easi free lunch occasion
# 2                        build leav
# 3                health insur medic
# 4      career excel growth opportun
#
#                                              Bigrams  \
# 0                                                NaN
# 1  benefit_easi free_lunch lunch_benefit occasion...
# 2                                         leav_build
# 3                          health_insur medic_health
# 4         career_growth excel_career growth_opportun
#
#                                             Trigrams
# 0                                                NaN
# 1  free_lunch_benefit lunch_benefit_easi occasion...
# 2                                                NaN
# 3                                 medic_health_insur
# 4         career_growth_opportun excel_career_growth
#    Unnamed: 0                                        Review_Text  \
# 0           0               Great people, made pretty good money
# 1           1  Good morning meetings addressing Safety and da...
# 2           2                                           Benefits
# 3           3                                      Money is good
# 4           4                                        good raises
#
#                                 Unigrams Bigrams  \
# 0                     money peopl pretti     NaN
# 1  address daili expect meet morn safeti     NaN
# 2                                benefit     NaN
# 3                                  money     NaN
# 4                                   rais     NaN
#
#                                             Trigrams
# 0                                 peopl_pretti_money
# 1  address_safeti_daili meet_address_safeti morn_...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                              Employee car discount
# 1           1  Knowing full well ahead of time what I need to...
# 2           2                                      Pay, benefits
# 3           3  Educational programs to have to most competent...
# 4           4  Decent work-life balance, the peon workers at ...
#
#                                             Unigrams  \
# 0                               car discount employe
# 1             accomplish ahead know shift start time
# 2                                        benefit pay
# 3                compet educ employe program qualifi
# 4  balanc decent friendli level lower peon pleasa...
#
#                          Bigrams               Trigrams
# 0                   car_discount   employe_car_discount
# 1                            NaN                    NaN
# 2                    pay_benefit                    NaN
# 3                            NaN                    NaN
# 4  decent_worklif worklif_balanc  decent_worklif_balanc
#    Unnamed: 0         Review_Text         Unigrams Bigrams Trigrams
# 0           0     weekly paycheck  paycheck weekli     NaN      NaN
# 1           1  Good compensation.          compens     NaN      NaN
# 2           2  good pay for temps         pay temp     NaN      NaN
# 3           3          Management            manag     NaN      NaN
# 4           4             Unknown          unknown     NaN      NaN
#    Unnamed: 0                                 Review_Text    Unigrams  \
# 0           0                                    Benefits     benefit
# 1           1                                         Pay         pay
# 2           2  free lunch if nobody gets hurt for a while  free lunch
# 3           3                  Good place and nice people  nice peopl
# 4           4                              great benefits     benefit
#
#       Bigrams Trigrams
# 0         NaN      NaN
# 1         NaN      NaN
# 2  free_lunch      NaN
# 3  nice_peopl      NaN
# 4         NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                   freedom to do the job, free food
# 1           1                             Great company and pers
# 2           2                   Free breakfast, lunch and dinner
# 3           3  employee perks, great pay, great people, compe...
# 4           4                                       Free lunches
#
#                            Unigrams  \
# 0                 food free freedom
# 1                               per
# 2       breakfast dinner free lunch
# 3  competitv employe pay peopl perk
# 4                        free lunch
#
#                                        Bigrams  \
# 0                       free_food freedom_free
# 1                                          NaN
# 2  breakfast_lunch free_breakfast lunch_dinner
# 3                                    pay_peopl
# 4                                   free_lunch
#
#                                       Trigrams
# 0                                          NaN
# 1                                          NaN
# 2  breakfast_lunch_dinner free_breakfast_lunch
# 3                                          NaN
# 4                                          NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                   Good job and pay
# 1           1                                      Vacation days
# 2           2                              Wages, Pto, benefits.
# 3           3  Based on job role, you can directly impact the...
# 4           4                                  Work life balance
#
#                                             Unigrams      Bigrams Trigrams
# 0                                                pay          NaN      NaN
# 1                                          day vacat    vacat_day      NaN
# 2                                   benefit pto wage  pto_benefit      NaN
# 3  base care deliveri directli impact optim outco...          NaN      NaN
# 4                                        balanc life  life_balanc      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                    Full time gets benefits and PTO
# 1           1                              10% discount on stock
# 2           2                    Career advancement & experience
# 3           3                                         Great team
# 4           4  The Pharmacy Manager's at this store are quite...
#
#                       Unigrams                                  Bigrams  \
# 0             benefit pto time                 benefit_pto time_benefit
# 1               discount stock                           discount_stock
# 2         advanc career experi              advanc_experi career_advanc
# 3                         team                                      NaN
# 4  awesom manag pharmaci store  manag_store pharmaci_manag store_awesom
#
#                                   Trigrams
# 0                         time_benefit_pto
# 1                        10_discount_stock
# 2                     career_advanc_experi
# 3                                      NaN
# 4  manag_store_awesom pharmaci_manag_store
#    Unnamed: 0                                        Review_Text  \
# 0           0                                       Free lunches
# 1           1                           hire and promotes within
# 2           2  The position I had allowed for weekends and al...
# 3           3                                Flexible envirement
# 4           4                                      Free accounts
#
#                       Unigrams       Bigrams Trigrams
# 0                   free lunch    free_lunch      NaN
# 1                  hire promot           NaN      NaN
# 2  allow holiday posit weekend           NaN      NaN
# 3                      flexibl           NaN      NaN
# 4                 account free  free_account      NaN
#    Unnamed: 0                                Review_Text  \
# 0           0  Benefits, Training Allowances, Healthcare
# 1           1                                 Everything
# 2           2                                   Benefits
# 3           3                                  Paychecks
# 4           4                                  High tech
#
#                         Unigrams        Bigrams Trigrams
# 0  allow benefit healthcar train  benefit_train      NaN
# 1                            NaN            NaN      NaN
# 2                        benefit            NaN      NaN
# 3                       paycheck            NaN      NaN
# 4                           tech            NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                  Employee discount
# 1           1                                          Customers
# 2           2                                      Good Benefits
# 3           3  Only pro is employee discount on store brand i...
# 4           4                    weekly promotions for employees
#
#                                 Unigrams  \
# 0                       discount employe
# 1                                 custom
# 2                                benefit
# 3  brand discount employe item pro store
# 4                  employe promot weekli
#
#                                              Bigrams  \
# 0                                   employe_discount
# 1                                                NaN
# 2                                                NaN
# 3  brand_item discount_store employe_discount sto...
# 4                                                NaN
#
#                                             Trigrams
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  discount_store_brand employe_discount_store st...
# 4                                                NaN
#    Unnamed: 0          Review_Text         Unigrams          Bigrams Trigrams
# 0           0           everything              NaN              NaN      NaN
# 1           1         great people            peopl              NaN      NaN
# 2           2        Great company              NaN              NaN      NaN
# 3           3        Flex schedule     flex schedul              NaN      NaN
# 4           4  Flexible scheduling  flexibl schedul  flexibl_schedul      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                     Great benefits
# 1           1                                          Laid back
# 2           2   nice place to work, free parking, coffee and tea
# 3           3  401k, referral bonus, tuition reimbursement, m...
# 4           4                                 Adjusted schedules
#
#                                        Unigrams  \
# 0                                       benefit
# 1                                          laid
# 2                      coffe free nice park tea
# 3  bonu contribut metro referr reimburs tuition
# 4                                adjust schedul
#
#                                              Bigrams  \
# 0                                                NaN
# 1                                                NaN
# 2           coffe_tea free_park nice_free park_coffe
# 3  bonu_tuition metro_contribut referr_bonu reimb...
# 4                                     adjust_schedul
#
#                                             Trigrams
# 0                                                NaN
# 1                                                NaN
# 2      free_park_coffe nice_free_park park_coffe_tea
# 3  401k_referr_bonu bonu_tuition_reimburs referr_...
# 4                                                NaN
#    Unnamed: 0                Review_Text        Unigrams         Bigrams  \
# 0           0              Good benefits         benefit             NaN
# 1           1           Great co workers       co worker       co_worker
# 2           2            Decent Benefits  benefit decent  decent_benefit
# 3           3  As many hours as you want            hour             NaN
# 4           4               Work Culture          cultur             NaN
#
#   Trigrams
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                           free drinks and sandwich
# 1           1             Benefits, Interesting Work, Co Workers
# 2           2                                  Excellent bonuses
# 3           3  Lunches is like long, but have to take care of...
# 4           4  Decent pay, good insurance benefits, good people.
#
#                                     Unigrams  \
# 0                        drink free sandwich
# 1                          benefit co worker
# 2                                bonus excel
# 3  build care custmer help insid lunch there
# 4             benefit decent insur pay peopl
#
#                                             Bigrams  \
# 0                         drink_sandwich free_drink
# 1                              benefit_co co_worker
# 2                                       excel_bonus
# 3    care_custmer help_insid insid_build lunch_care
# 4  benefit_peopl decent_pay insur_benefit pay_insur
#
#                                             Trigrams
# 0                                free_drink_sandwich
# 1                                  benefit_co_worker
# 2                                                NaN
# 3  care_custmer_there help_insid_build lunch_care...
# 4  decent_pay_insur insur_benefit_peopl pay_insur...
#    Unnamed: 0         Review_Text Unigrams Bigrams Trigrams
# 0           0                  Na       na     NaN      NaN
# 1           1           Coworkers   cowork     NaN      NaN
# 2           2   Being on our own.      NaN     NaN      NaN
# 3           3  Pay and that's it.      pay     NaN      NaN
# 4           4              Salary   salari     NaN      NaN
#    Unnamed: 0                            Review_Text                 Unigrams  \
# 0           0  Perks card that the company gives you                card perk
# 1           1                 Great Pay and benefits              benefit pay
# 2           2     Decent pay, could always be better  better could decent pay
# 3           3    get to interact with people walking      interact peopl walk
# 4           4                               Benefits                  benefit
#
#        Bigrams Trigrams
# 0          NaN      NaN
# 1  pay_benefit      NaN
# 2   decent_pay      NaN
# 3          NaN      NaN
# 4          NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                Friendly co-workers
# 1           1  Paid sick days, attentive staff, opportunities...
# 2           2                                 Made good, friends
# 3           3                   working with dedicated employees
# 4           4             Sick time and vacation time is alright
#
#                             Unigrams               Bigrams         Trigrams
# 0                    cowork friendli       friendli_cowork              NaN
# 1  day grow opportun paid sick staff             paid_sick              NaN
# 2                             friend                   NaN              NaN
# 3                            employe                   NaN              NaN
# 4                    sick time vacat  sick_time vacat_time  sick_time_vacat
#    Unnamed: 0                               Review_Text  \
# 0           0  excellent work enviroment( then-not now)
# 1           1                     Good pay and benefits
# 2           2                                  Benefits
# 3           3        Great employee recognition program
# 4           4                 flexible work environment
#
#                    Unigrams           Bigrams Trigrams
# 0              enviro excel               NaN      NaN
# 1               benefit pay       pay_benefit      NaN
# 2                   benefit               NaN      NaN
# 3  employe program recognit  employe_recognit      NaN
# 4           environ flexibl               NaN      NaN
#    Unnamed: 0                                Review_Text  \
# 0           0                          Good hourly wage.
# 1           1                               Job Security
# 2           2                                   Benefits
# 3           3  Great benefits holidays off paid holidays
# 4           4                                 Break room
#
#                Unigrams       Bigrams Trigrams
# 0           hourli wage           NaN      NaN
# 1                 secur           NaN      NaN
# 2               benefit           NaN      NaN
# 3  benefit holiday paid  paid_holiday      NaN
# 4                 break           NaN      NaN
#    Unnamed: 0                                  Review_Text         Unigrams  \
# 0           0                   Almost unlimited resources  resourc unlimit
# 1           1                        The benefits are good          benefit
# 2           2                   Flexible work arrangements   arrang flexibl
# 3           3                                Paid time off        paid time
# 4           4  Oppurtunity to reach goal/bonus every month      month reach
#
#      Bigrams Trigrams
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3  paid_time      NaN
# 4        NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                                               None
# 1           1                           they offer 9/80 schedule
# 2           2                Opportunity to make a lot of money.
# 3           3                                               None
# 4           4  No forced dispatch, Good equipment, Benefits (...
#
#                                      Unigrams  \
# 0                                        none
# 1                               offer schedul
# 2                          lot money opportun
# 3                                        none
# 4  benefit dispatch equip forc mpcbenefitscom
#
#                                              Bigrams  \
# 0                                                NaN
# 1                                          offer_980
# 2                             lot_money opportun_lot
# 3                                                NaN
# 4  benefit_mpcbenefitscom dispatch_equip equip_be...
#
#                                             Trigrams
# 0                                                NaN
# 1                                  offer_980_schedul
# 2                                 opportun_lot_money
# 3                                                NaN
# 4  dispatch_equip_benefit equip_benefit_mpcbenefi...
#    Unnamed: 0                       Review_Text                    Unigrams  \
# 0           0                  Pay and benefits                 benefit pay
# 1           1               Great place to work                         NaN
# 2           2                    Company events                       event
# 3           3  Excellent cable package discount  cabl discount excel packag
# 4           4                           Bonuses                       bonus
#
#        Bigrams Trigrams
# 0  pay_benefit      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN
#    Unnamed: 0                              Review_Text  \
# 0           0                  Choosing work schedules
# 1           1                 great healthcare benefit
# 2           2                               Healthcare
# 3           3  Work/life balance and competitive wages
# 4           4                                  Benfits
#
#                        Unigrams            Bigrams Trigrams
# 0                 choos schedul                NaN      NaN
# 1             benefit healthcar  healthcar_benefit      NaN
# 2                     healthcar                NaN      NaN
# 3  balanc competit wage worklif     worklif_balanc      NaN
# 4                        benfit                NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                      5 weeks of PTO from the start
# 1           1        Fun, swag, candy, chips and amazing people!
# 2           2  Christmas luncheon, Appreciation breakfast, Re...
# 3           3                                                pay
# 4           4                                 Relaxed atmosphere
#
#                                             Unigrams Bigrams Trigrams
# 0                                     pto start week     NaN      NaN
# 1                                amaz fun peopl swag     NaN      NaN
# 2  appreci breakfast certif christma luncheon rec...     NaN      NaN
# 3                                                pay     NaN      NaN
# 4                                    atmospher relax     NaN      NaN
#    Unnamed: 0                        Review_Text   Unigrams    Bigrams  \
# 0           0                           Pay, Pto    pay pto    pay_pto
# 1           1  3.00 lunch, we have a gym as well  gym lunch  lunch_gym
# 2           2                          great pay        pay        NaN
# 3           3                               Easy       easi        NaN
# 4           4                                Pay        pay        NaN
#
#         Trigrams
# 0            NaN
# 1  300_lunch_gym
# 2            NaN
# 3            NaN
# 4            NaN
#    Unnamed: 0                           Review_Text             Unigrams  \
# 0           0                    Excellent training          excel train
# 1           1                 tution remimbursement                  NaN
# 2           2                        great vacation                vacat
# 3           3                   Great place to work                  NaN
# 4           4  Benifits, job security, and training  benifit secur train
#
#        Bigrams Trigrams
# 0  excel_train      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0  This company is a solid and grwing company Wor...
# 1           1               Great people and interesting project
# 2           2                               treated with respect
# 3           3                Pay, hours, managment isn't too bad
# 4           4                                           good pay
#
#                                    Unigrams Bigrams  \
# 0  flexibl grwing orient solid wordwidebusi     NaN
# 1                             peopl project     NaN
# 2                             respect treat     NaN
# 3                        bad hour manag pay     NaN
# 4                                       pay     NaN
#
#                                             Trigrams
# 0  grwing_wordwidebusi_orient solid_grwing_wordwi...
# 1                                                NaN
# 2                                                NaN
# 3                      hour_manag_bad pay_hour_manag
# 4                                                NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0            Great people & pedigree for your resume
# 1           1  Co-workers, benefits, experience gained, worki...
# 2           2                 old timers have a lot of knowledge
# 3           3  stable, good work life balance, and very suppo...
# 4           4                                            Support
#
#                            Unigrams         Bigrams Trigrams
# 0                       peopl resum             NaN      NaN
# 1  benefit cowork experi gain remot  cowork_benefit      NaN
# 2                      knowledg lot             NaN      NaN
# 3   balanc life remot stabl support     life_balanc      NaN
# 4                           support             NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                    Some nice people, good location
# 1           1                                              Hours
# 2           2                                               None
# 3           3             Pay, hours, breaks, easy job, training
# 4           4  Competitive Wages, good benefits, newer facili...
#
#                       Unigrams              Bigrams Trigrams
# 0             locat nice peopl           nice_peopl      NaN
# 1                         hour                  NaN      NaN
# 2                         none                  NaN      NaN
# 3    break easi hour pay train  hour_break pay_hour      NaN
# 4  benefit competit facil wage                  NaN      NaN
#    Unnamed: 0                                       Review_Text  \
# 0           0       high intensity job really good for learning
# 1           1                                     Flexible time
# 2           2                                          Benefits
# 3           3  Cutting edge technology, high salary with bonus.
# 4           4                         Positive work environment
#
#                         Unigrams  \
# 0                   intens learn
# 1                   flexibl time
# 2                        benefit
# 3  bonu cut edg salari technolog
# 4                  environ posit
#
#                                              Bigrams  \
# 0                                       intens_learn
# 1                                       flexibl_time
# 2                                                NaN
# 3  cut_edg edg_technolog salari_bonu technolog_sa...
# 4                                      posit_environ
#
#                                             Trigrams
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  cut_edg_technolog edg_technolog_salari technol...
# 4                                                NaN
#    Unnamed: 0                    Review_Text        Unigrams Bigrams Trigrams
# 0           0  Fun, active, and hard working  activ fun hard     NaN      NaN
# 1           1                      Easy Work            easi     NaN      NaN
# 2           2                       Benefits         benefit     NaN      NaN
# 3           3      Great people to work with           peopl     NaN      NaN
# 4           4                        Nothing             NaN     NaN      NaN
#    Unnamed: 0                               Review_Text       Unigrams  \
# 0           0                                 Great pay            pay
# 1           1                             Great company            NaN
# 2           2                 Great hours and discounts  discount hour
# 3           3                  Work inviroment is great            NaN
# 4           4  Can be late by 7 minutes without penalty          minut
#
#   Bigrams Trigrams
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0                          Cafeteria Benefits salary
# 1           1                     Updating technology frequently
# 2           2                                   New technologies
# 3           3                                  A lot of time off
# 4           4  Great people, great benefits, great medical, d...
#
#                             Unigrams                           Bigrams  \
# 0           benefit cafeteria salari  benefit_salari cafeteria_benefit
# 1           frequent technolog updat                               NaN
# 2                          technolog                               NaN
# 3                           lot time                          lot_time
# 4  benefit dental medic peopl vision       benefit_medic peopl_benefit
#
#   Trigrams
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#    Unnamed: 0                               Review_Text  \
# 0           0  Cafeteria, Time Paid Off, Work from home
# 1           1                                    Campus
# 2           2                               Telecommute
# 3           3       Free fruits on Tuesday and Thursday
# 4           4  Paid training, fair pay, calm atmosphere
#
#                              Unigrams              Bigrams  \
# 0            cafeteria home paid time            time_paid
# 1                               campu                  NaN
# 2                          telecommut                  NaN
# 3         free fruit thursday tuesday           free_fruit
# 4  atmospher calm fair paid pay train  fair_pay paid_train
#
#                                             Trigrams
# 0                 cafeteria_time_paid time_paid_home
# 1                                                NaN
# 2                                                NaN
# 3          free_fruit_tuesday fruit_tuesday_thursday
# 4  fair_pay_calm paid_train_fair pay_calm_atmosph...
#    Unnamed: 0                                        Review_Text  \
# 0           0                                               None
# 1           1  they had a breakfast shop there and it was con...
# 2           2                               personal development
# 3           3                                            friends
# 4           4                                  good hourly rates
#
#                   Unigrams         Bigrams                 Trigrams
# 0                     none             NaN                      NaN
# 1  breakfast convient shop             NaN  breakfast_shop_convient
# 2           develop person  person_develop                      NaN
# 3                   friend             NaN                      NaN
# 4              hourli rate             NaN                      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0      Great culture, pay, and tuition reimbursement
# 1           1                                        Flexibility
# 2           2                                      talented team
# 3           3  Learning each Day, Company Gift Recognition an...
# 4           4                                               None
#
#                         Unigrams  \
# 0    cultur pay reimburs tuition
# 1                        flexibl
# 2                    talent team
# 3  award day gift learn recognit
# 4                           none
#
#                                            Bigrams  \
# 0          cultur_pay pay_tuition tuition_reimburs
# 1                                              NaN
# 2                                      talent_team
# 3  day_gift gift_recognit learn_day recognit_award
# 4                                              NaN
#
#                                             Trigrams
# 0            cultur_pay_tuition pay_tuition_reimburs
# 1                                                NaN
# 2                                                NaN
# 3  day_gift_recognit gift_recognit_award learn_da...
# 4                                                NaN
#    Unnamed: 0                                  Review_Text  \
# 0           0                            Nice Ice machines
# 1           1                                    great pay
# 2           2                             A good work out.
# 3           3                                    Great Pay
# 4           4  Benefits, Hour Lunch Break, Get paid weekly
#
#                                Unigrams  \
# 0                       ice machin nice
# 1                                   pay
# 2                                   NaN
# 3                                   pay
# 4  benefit break hour lunch paid weekli
#
#                                            Bigrams          Trigrams
# 0                                              NaN               NaN
# 1                                              NaN               NaN
# 2                                              NaN               NaN
# 3                                              NaN               NaN
# 4  benefit_hour hour_lunch lunch_break paid_weekli  hour_lunch_break
#    Unnamed: 0                                        Review_Text  \
# 0           0                              Pto, competitive pay.
# 1           1               Diversity Policy and Code of Conduct
# 2           2                                                Pay
# 3           3  Able to gain friendships with customers, decen...
# 4           4                                        Paid breaks
#
#                      Unigrams       Bigrams Trigrams
# 0            competit pay pto  competit_pay      NaN
# 1  code conduct divers polici           NaN      NaN
# 2                         pay           NaN      NaN
# 3  abl custom decent gain pay    decent_pay      NaN
# 4                  break paid    paid_break      NaN
#    Unnamed: 0                                        Review_Text  \
# 0           0  Pays great, has great benefits and a retiremen...
# 1           1                                     flexible hours
# 2           2                                              none!
# 3           3                                      good benefits
# 4           4                     Pay, vacation, benefit package
#
#                    Unigrams                                 Bigrams  \
# 0    benefit pay plan retir    benefit_retir pay_benefit retir_plan
# 1              flexibl hour                            flexibl_hour
# 2                      none                                     NaN
# 3                   benefit                                     NaN
# 4  benefit packag pay vacat  benefit_packag pay_vacat vacat_benefit
#
#                                  Trigrams
# 0    benefit_retir_plan pay_benefit_retir
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4  pay_vacat_benefit vacat_benefit_packag
#    Unnamed: 0                            Review_Text               Unigrams  \
# 0           0  Supportive culture and good mentoring  cultur mentor support
# 1           1                       Please see above                  pleas
# 2           2                               Training                  train
# 3           3               posiive work environment         environ posiiv
# 4           4                            Nice people             nice peopl
#
#       Bigrams               Trigrams
# 0         NaN  support_cultur_mentor
# 1         NaN                    NaN
# 2         NaN                    NaN
# 3         NaN                    NaN
# 4  nice_peopl                    NaN
# 349847
# ['pay  ',
#  'close hous  ',
#  '  ',
#  'cowork flexibl life schedul flexibl_schedul ',
#  'benefit  ']

# %%
data_px = sentences

# %%
vectorizer = TfidfVectorizer(analyzer='word',       
                             min_df=10,                        # minimum reqd occurences of a word 
                             stop_words='english',             # remove stop words
                             lowercase=True,                   # convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}',  # num chars > 3
                             # max_features=50000,             # max number of uniq words
                            )

data_vectorized = vectorizer.fit_transform(data_px)
print(data_vectorized)
# Out:
#   (0, 691)	1.0
#   (1, 179)	0.597370084186877
#   (1, 484)	0.8019656990910294
#   (3, 245)	0.30141453836556753
#   (3, 397)	0.5922868997469584
#   (3, 551)	0.409435666570386
#   (3, 842)	0.625066347990413
#   (4, 79)	1.0
#   (5, 263)	0.7564494378939898
#   (5, 328)	0.654052175219888
#   (6, 416)	0.2728093443040306
#   (6, 576)	0.6162155035550861
#   (6, 652)	0.499402956494321
#   (6, 886)	0.4435919721573907
#   (6, 964)	0.3157156380685073
#   (7, 112)	0.30330937022559024
#   (7, 465)	0.39521146178139016
#   (7, 509)	0.4141696412664891
#   (7, 578)	0.26865461113687694
#   (7, 911)	0.4438572412459378
#   (7, 1023)	0.5577546808154992
#   (8, 256)	0.44794099206554133
#   (8, 290)	0.3942060492456101
#   (8, 470)	0.5168578585267343
#   (8, 564)	0.30085794995859977
#   :	:
#   (349832, 578)	0.6828851387453391
#   (349833, 949)	0.6258109490683443
#   (349833, 365)	0.7799747790962077
#   (349834, 422)	0.6729140714854994
#   (349834, 140)	0.7397206583547656
#   (349836, 79)	0.34209207509717654
#   (349836, 215)	0.9396664366442529
#   (349837, 109)	1.0
#   (349838, 263)	0.5875049614748101
#   (349838, 666)	0.8092205634080747
#   (349839, 465)	0.6903548269181281
#   (349839, 509)	0.7234709482424581
#   (349840, 254)	0.6339827123877817
#   (349840, 282)	0.7733472185205241
#   (349841, 661)	1.0
#   (349842, 79)	0.458000050702587
#   (349842, 203)	0.8889521660676842
#   (349843, 343)	1.0
#   (349844, 373)	0.5828722545195837
#   (349844, 1037)	0.5945841175498185
#   (349844, 64)	0.5538317994380254
#   (349845, 79)	0.458000050702587
#   (349845, 203)	0.8889521660676842
#   (349846, 973)	0.7067253824599038
#   (349846, 354)	0.7074879743055019

# %%
# Materialize the sparse data
data_dense = data_vectorized.todense()

# Compute Sparsicity = Percentage of Non-Zero cells
print("Sparsicity: ", ((data_dense == 0).sum()/data_dense.size)*100, "%")
# Out:
# Sparsicity:  99.787754406948 %

# %%
# Build LDA Model
lda_model = LatentDirichletAllocation(n_topics=8,               # Number of topics
                                      max_iter=100,               # Max learning iterations
                                      learning_method='online',   
                                      random_state=42,          # Random state
                                      batch_size=128,            # n docs in each learning iter
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)

print(lda_model)  # Model attributes
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=100, mean_change_tol=0.001,
#              n_components=10, n_jobs=-1, n_topics=8, perp_tol=0.1,
#              random_state=42, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))

# Compute Coherence Score
# coherence_model_lda = CoherenceModel(model=lda_model, texts=data_vectorized, dictionary=id2word, coherence='u_mass')
# coherence_lda = coherence_model_lda.get_coherence()
# print('\nCoherence Score: ', coherence_lda)

# See model parameters
pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -305992.13210978365
# Perplexity:  747.3711736467765
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 100,
#  'mean_change_tol': 0.001,
#  'n_components': 10,
#  'n_jobs': -1,
#  'n_topics': 8,
#  'perp_tol': 0.1,
#  'random_state': 42,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %%
pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model, data_vectorized, vectorizer, mds='tsne')
panel
# Out:
# /anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 3     -108.961037  -45.149498       1        1  16.893133
# 4      156.939209  -96.912521       2        1  14.996249
# 2       56.449711   95.678558       3        1  12.813651
# 7       29.901962  -40.687557       4        1  11.677274
# 5       65.154160 -175.081436       5        1  11.465708
# 6      153.081329   23.586296       6        1  11.279463
# 0      -53.182663 -152.030411       7        1  10.687628
# 1      -60.167274   65.096619       8        1  10.186895, topic_info=    Category        Freq        Term       Total  loglift  logprob
# 286  Default  913.000000        pace  913.000000  30.0000  30.0000
# 149  Default  944.000000        fast  944.000000  29.0000  29.0000
# 430  Default  380.000000       typic  380.000000  28.0000  28.0000
# 93   Default  893.000000         day  893.000000  27.0000  27.0000
# 279  Default  326.000000    opportun  326.000000  26.0000  26.0000
# 133  Default  542.000000     environ  542.000000  25.0000  25.0000
# 43   Default  286.000000       break  286.000000  24.0000  24.0000
# 270  Default  350.000000        nice  350.000000  23.0000  23.0000
# 360  Default  213.000000      season  213.000000  22.0000  22.0000
# 47   Default  204.000000        care  204.000000  21.0000  21.0000
# 213  Default  177.000000        item  177.000000  20.0000  20.0000
# 169  Default  347.000000    friendli  347.000000  19.0000  19.0000
# 450  Default  239.000000        week  239.000000  18.0000  18.0000
# 199  Default  674.000000        hour  674.000000  17.0000  17.0000
# 154  Default  156.000000        feet  156.000000  16.0000  16.0000
# 288  Default  153.000000      packag  153.000000  15.0000  15.0000
# 356  Default  133.000000        scan  133.000000  14.0000  14.0000
# 365  Default  126.000000      servic  126.000000  13.0000  13.0000
# 304  Default  197.000000        pick  197.000000  12.0000  12.0000
# 296  Default  769.000000       peopl  769.000000  11.0000  11.0000
# 454  Default  288.000000      worker  288.000000  10.0000  10.0000
# 6    Default  229.000000      advanc  229.000000   9.0000   9.0000
# 261  Default  128.000000       minut  128.000000   8.0000   8.0000
# 249  Default  878.000000       manag  878.000000   7.0000   7.0000
# 386  Default  190.000000       stand  190.000000   6.0000   6.0000
# 91   Default  305.000000      custom  305.000000   5.0000   5.0000
# 51   Default  122.000000      center  122.000000   4.0000   4.0000
# 287  Default  123.000000        pack  123.000000   3.0000   3.0000
# 367  Default  353.000000       shift  353.000000   2.0000   2.0000
# 42   Default   99.000000         box   99.000000   1.0000   1.0000
# ..       ...         ...         ...         ...      ...      ...
# 169   Topic8  169.774836    friendli  347.152704   1.5688  -3.3232
# 133   Topic8  257.965247     environ  542.221784   1.5412  -2.9048
# 361   Topic8   30.428348       secur   65.463440   1.5180  -5.0423
# 69    Topic8   38.682608    competit  114.247028   1.2011  -4.8023
# 140   Topic8   17.218589     exercis   52.332117   1.1724  -5.6117
# 331   Topic8   14.170882       quota   49.967608   1.0239  -5.8065
# 400   Topic8   11.230710      strict   42.385953   0.9559  -6.0390
# 144   Topic8   17.011808      extrem   69.534949   0.8761  -5.6238
# 43    Topic8   65.118512       break  286.198105   0.8036  -4.2815
# 39    Topic8   11.297136        bodi   52.572746   0.7464  -6.0331
# 383   Topic8    6.494825       speed   31.611955   0.7015  -6.5867
# 171   Topic8   96.758632         fun  500.393723   0.6409  -3.8855
# 443   Topic8    5.131243       volum   26.906609   0.6270  -6.8223
# 334   Topic8    8.648187       reach   47.345039   0.5840  -6.3003
# 406   Topic8   16.804991  supervisor   93.066856   0.5724  -5.6360
# 398   Topic8   21.938273      stress  128.755073   0.5144  -5.3694
# 248   Topic8   13.670009        make   78.546889   0.5356  -5.8425
# 296   Topic8   93.273268       peopl  769.039440   0.1745  -3.9221
# 46    Topic8   31.841547        busi  216.219212   0.3685  -4.9969
# 190   Topic8   58.426084        help  501.971099   0.1333  -4.3899
# 418   Topic8   75.814602        time  755.602836  -0.0152  -4.1294
# 242   Topic8   48.638677        love  429.044190   0.1069  -4.5733
# 249   Topic8   69.728949       manag  878.313623  -0.2493  -4.2131
# 241   Topic8   53.437069         lot  571.513623  -0.0857  -4.4792
# 130   Topic8   53.172646       enjoy  576.161583  -0.0988  -4.4841
# 226   Topic8   45.551350       learn  614.145896  -0.3173  -4.6388
# 186   Topic8   37.724382        hard  422.173552  -0.1310  -4.8274
# 93    Topic8   43.264544         day  893.313979  -0.7435  -4.6903
# 255   Topic8   31.890347        meet  282.862609   0.1014  -4.9954
# 86    Topic8   31.945240      cowork  292.550223   0.0695  -4.9936
#
# [445 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 0         3  0.973337       abil
# 3         4  0.886322     achiev
# 3         5  0.104273     achiev
# 6         1  0.174621     advanc
# 6         3  0.065483     advanc
# 6         4  0.078580     advanc
# 6         6  0.650464     advanc
# 6         7  0.030559     advanc
# 8         2  0.180538       alot
# 8         6  0.812419       alot
# 9         1  0.222667       amaz
# 9         3  0.114925       amaz
# 9         4  0.150839       amaz
# 9         6  0.459699       amaz
# 9         8  0.043097       amaz
# 10        4  0.296490  amazoncom
# 10        6  0.686608  amazoncom
# 12        2  0.166588     answer
# 12        5  0.049976     answer
# 12        8  0.782962     answer
# 13        1  0.842260      appli
# 13        3  0.153138      appli
# 14        1  0.224651    appreci
# 14        3  0.224651    appreci
# 14        7  0.530994    appreci
# 15        1  0.876121      arent
# 15        6  0.097347      arent
# 16        3  0.201622     assign
# 16        5  0.697922     assign
# 16        8  0.077547     assign
# ...     ...       ...        ...
# 446       5  0.196413   warehous
# 446       6  0.154623   warehous
# 446       8  0.079401   warehous
# 447       1  0.326821      wasnt
# 447       6  0.665747      wasnt
# 448       2  0.747331      water
# 448       5  0.209253      water
# 449       1  0.950856       wear
# 450       1  0.246216       week
# 450       2  0.751168       week
# 452       1  0.275882       wish
# 452       2  0.075241       wish
# 452       7  0.639544       wish
# 453       1  0.142309     wonder
# 453       6  0.853855     wonder
# 454       1  0.100605     worker
# 454       2  0.131827     worker
# 454       4  0.065913     worker
# 454       5  0.083259     worker
# 454       7  0.568937     worker
# 454       8  0.052037     worker
# 455       1  0.938410    worklif
# 456       3  0.750970   workplac
# 456       5  0.037928   workplac
# 456       6  0.083441   workplac
# 456       7  0.128955   workplac
# 457       3  0.224442      world
# 457       6  0.754943      world
# 460       5  0.961683       wrap
# 461       4  0.960155      write
#
# [956 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 5, 3, 8, 6, 7, 1, 2])
